# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("Air India flight crashes in Ahmedabad India - 2025-06-16 - video details.xlsx")

# %%
df.head()
# Out:
#        videoId                                              title  \
# 0  7X5jJRx1_r0  Air India plane crashes shortly after take off...
# 1  nFuLfEjvzMU  Video shows Air India plane crashing in Ahmedabad
# 2  75P3sOZLwls  Ahmedabad Plane Crash: What Air India Pilot's ...
# 3  WYWHsxUYkbI  Air India plane crash death toll rises to 270 ...
# 4  RoRIfBrM5d4  Ahmedabad Plane Crash: What Air India Pilot's ...
#
#    lengthSeconds                                           keywords  \
# 0            344  Ahmedabad airport AMD; Air India Flight AI147;...
# 1            211  Airplane Crash; Plane Crash; Boeing 787; CBS N...
# 2          18635  ahmedabad plane crash; air india plane crash; ...
# 3            276  bbc; bbc news; news; world news; breaking news...
# 4          38725  ahmedabad plane crash; air india plane crash; ...
#
#                                     shortDescription  allowRatings  viewCount  \
# ...

# %%
df[['shortDescription','keywords']].head()
# Out:
#                                     shortDescription  \
# 0  An Air India plane has crashed shortly after t...
# 1  (Warning: Video in this report may be disturbi...
# 2  Ahmedabad Plane Crash: What Air India Pilot's ...
# 3  Doctors in India say 270 bodies have been reco...
# 4  Ahmedabad Plane Crash: What Air India Pilot's ...
#
#                                             keywords
# 0  Ahmedabad airport AMD; Air India Flight AI147;...
# 1  Airplane Crash; Plane Crash; Boeing 787; CBS N...
# 2  ahmedabad plane crash; air india plane crash; ...
# 3  bbc; bbc news; news; world news; breaking news...
# 4  ahmedabad plane crash; air india plane crash; ...
